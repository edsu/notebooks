# %% [markdown]
# # Wordle
#
# I was curious how much Wordle results were being tweets.

# %%
! pip install twarc
! twarc2 configure
! twarc2 counts --granularity day --csv --archive '🟩🟩🟩🟩🟩' data/wordle-counts.csv

# %%
import pandas

df = pandas.read_csv('data/wordle-counts.csv', parse_dates=['start', 'end'])
df
# Out:
#                          start                       end  day_count
# 0    2021-12-28 00:00:00+00:00 2021-12-29 00:00:00+00:00       7365
# 1    2021-12-29 00:00:00+00:00 2021-12-30 00:00:00+00:00      10757
# 2    2021-12-30 00:00:00+00:00 2021-12-31 00:00:00+00:00      12949
# 3    2021-12-31 00:00:00+00:00 2022-01-01 00:00:00+00:00      12493
# 4    2022-01-01 00:00:00+00:00 2022-01-02 00:00:00+00:00      14197
# ...                        ...                       ...        ...
# 5787 2006-04-11 00:00:00+00:00 2006-04-12 00:00:00+00:00          0
# 5788 2006-04-12 00:00:00+00:00 2006-04-13 00:00:00+00:00          0
# 5789 2006-04-13 00:00:00+00:00 2006-04-14 00:00:00+00:00          0
# 5790 2006-04-14 00:00:00+00:00 2006-04-15 00:00:00+00:00          0
# 5791 2006-04-15 00:00:00+00:00 2006-04-16 00:00:00+00:00          0
#
# [5792 rows x 3 columns]

# %%
df = df.sort_values('start')
df
# Out:
#                          start                       end  day_count
# 5766 2006-03-21 00:00:00+00:00 2006-03-22 00:00:00+00:00          0
# 5767 2006-03-22 00:00:00+00:00 2006-03-23 00:00:00+00:00          0
# 5768 2006-03-23 00:00:00+00:00 2006-03-24 00:00:00+00:00          0
# 5769 2006-03-24 00:00:00+00:00 2006-03-25 00:00:00+00:00          0
# 5770 2006-03-25 00:00:00+00:00 2006-03-26 00:00:00+00:00          0
# ...                        ...                       ...        ...
# 26   2022-01-23 00:00:00+00:00 2022-01-24 00:00:00+00:00     342250
# 27   2022-01-24 00:00:00+00:00 2022-01-25 00:00:00+00:00     336650
# 28   2022-01-25 00:00:00+00:00 2022-01-26 00:00:00+00:00     365947
# 29   2022-01-26 00:00:00+00:00 2022-01-27 00:00:00+00:00     404090
# 30   2022-01-27 00:00:00+00:00 2022-01-27 15:57:30+00:00     311363
#
# [5792 rows x 3 columns]

# %%
import plotly.express as xp

xp.line(df, x='start', y='day_count')
# Out:
# <div>                            <div id="f134f888-af78-46b6-9f69-bc351cc65f1e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f134f888-af78-46b6-9f69-bc351cc65f1e")) {                    Plotly.newPlot(                        "f134f888-af78-46b6-9f69-bc351cc65f1e",                        [{"hovertemplate":"start=%{x}<br>day_count=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2006-03-21T00:00:00+00:00","2006-03-22T00:00:00+00:00","2006-03-23T00:00:00+00:00","2006-03-24T00:00:00+00:00","2006-03-25T00:00:00+00:00","2006-03-26T00:00:00+00:00","2006-03-27T00:00:00+00:00","2006-03-28T00:00:00+00:00","2006-03-29T00:00:00+00:00","2006-03-30T00:
# ...

# %%
from datetime import datetime, timezone

recent = df[(df['start'] > datetime(2021, 10, 1, tzinfo=timezone.utc)) & (df['start'] < datetime(2022, 1, 27, tzinfo=timezone.utc))]
xp.line(recent, x='start', y='day_count', title='Worldle Tweets per Day', labels={'day_count': 'Tweets per Day', 'start': 'Day'})
# Out:
# <div>                            <div id="32de7386-f2f5-454f-8886-93f115e2378f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("32de7386-f2f5-454f-8886-93f115e2378f")) {                    Plotly.newPlot(                        "32de7386-f2f5-454f-8886-93f115e2378f",                        [{"hovertemplate":"Day=%{x}<br>Tweets per Day=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2021-10-02T00:00:00+00:00","2021-10-03T00:00:00+00:00","2021-10-04T00:00:00+00:00","2021-10-05T00:00:00+00:00","2021-10-06T00:00:00+00:00","2021-10-07T00:00:00+00:00","2021-10-08T00:00:00+00:00","2021-10-09T00:00:00+00:00","2021-10-10T00:00:00+0
# ...
