# %% [markdown]
# # Stanford and DoE
#
# > Tom: What can RIALTO tell us about what level of DOE funding has created Stanford / SLAC research outputs?

# %%
import pandas

df = pandas.read_csv('../sul-dlss/rialto-airflow/data/snapshots/20241114173510/dimensions-pubs.csv')
df
# Out:
# /var/folders/zh/9h5yvls57t7fbc7rj3ksh5y00000gr/T/ipykernel_56862/757140099.py:3: DtypeWarning: Columns (4,7,8,9,31,37,49,64,67,72) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pandas.read_csv('../sul-dlss/rialto-airflow/data/snapshots/20241114173510/dimensions-pubs.csv')
#                                                  abstract  \
# 0       Mammalian place cells are active at one or a f...
# 1                                                     NaN
# 2        The fibrous cap of atherosclerotic plaques is...
# 3       We present a comprehensive neural network to m...
# 4                                                     NaN
# ...                                                   ...
# 537668  CONTEXT: Communal blogs facilitate online narr...
# 537669  OBJECTIVE: The purpose of this study was to de...
# 537670  OBJECTIVE: To study risk factors for cell type...
# 537671  BACKGROUND: Candida albicans is one of the mos...
# 537672  BACKGROUND: Autoimmune type 1 diabetes mellitu...
#
#                                          acknowledgements  altmetric  \
# 0                                                     NaN        4.0
# 1                                                     NaN        NaN
# 2                                                     NaN        NaN
# 3                                                     NaN        NaN
# 4       Author contributions\n        S.R., E.C.S., S....        2.0
# ...                                                   ...        ...
# 537668                                                NaN        3.0
# 537669  Dr Bianco is supported by National Institute o...        NaN
# 537670                                                NaN        NaN
# 537671                                                NaN        1.0
# 537672                                                NaN        NaN
#
#         altmetric_id arxiv_id  \
# 0        170059067.0      NaN
# 1                0.0      NaN
# 2                0.0      NaN
# 3                0.0      NaN
# 4        165279069.0      NaN
# ...              ...      ...
# 537668   110440656.0      NaN
# 537669           0.0      NaN
# 537670           0.0      NaN
# 537671     2523305.0      NaN
# 537672           0.0      NaN
#
#                                                   authors  authors_count  \
# 0       [{'affiliations': [{'city': 'Stanford', 'city_...              2
# 1       [{'affiliations': [{'city': 'San Francisco', '...              7
# 2       [{'affiliations': [{'city': 'Stanford', 'city_...             14
# 3       [{'affiliations': [{'city': 'Los Angeles', 'ci...              6
# 4       [{'affiliations': [{'city': 'Philadelphia', 'c...              7
# ...                                                   ...            ...
# 537668  [{'affiliations': [{'city': 'Charleston', 'cit...              8
# 537669  [{'affiliations': [{'city': 'San Francisco', '...              6
# 537670  [{'affiliations': [{'city': None, 'city_id': N...              7
# 537671  [{'affiliations': [{'city': 'Tehran', 'city_id...              8
# 537672  [{'affiliations': [{'city': 'Tehran', 'city_id...              5
#
#        book_doi book_series_title book_title  ... resulting_publication_doi  \
# 0           NaN               NaN        NaN  ...                       NaN
# 1           NaN               NaN        NaN  ...                       NaN
# 2           NaN               NaN        NaN  ...                       NaN
# 3           NaN               NaN        NaN  ...                       NaN
# 4           NaN               NaN        NaN  ...                       NaN
# ...         ...               ...        ...  ...                       ...
# 537668      NaN               NaN        NaN  ...                       NaN
# 537669      NaN               NaN        NaN  ...                       NaN
# 537670      NaN               NaN        NaN  ...                       NaN
# 537671      NaN               NaN        NaN  ...                       NaN
# 537672      NaN               NaN        NaN  ...                       NaN
#
#        score                                       source_title subtitles  \
# 0        1.0  {'id': 'jour.1101321', 'title': 'Current Biolo...       NaN
# 1        1.0  {'id': 'jour.1008793', 'title': 'Transplantati...       NaN
# 2        1.0  {'id': 'jour.1100952', 'title': 'Arteriosclero...       NaN
# 3        1.0  {'id': 'jour.1031287', 'title': 'ACM Transacti...       NaN
# 4        1.0  {'id': 'jour.1082971', 'title': 'Proceedings o...       NaN
# ...      ...                                                ...       ...
# 537668   1.0  {'id': 'jour.1117679', 'title': 'The Permanent...       NaN
# 537669   1.0  {'id': 'jour.1093318', 'title': 'Journal of Ul...       NaN
# 537670   1.0  {'id': 'jour.1117679', 'title': 'The Permanent...       NaN
# 537671   1.0  {'id': 'jour.1037416', 'title': 'Iranian Journ...       NaN
# 537672   1.0  {'id': 'jour.1037416', 'title': 'Iranian Journ...       NaN
#
#        supporting_grant_ids times_cited  \
# 0                       NaN           0
# 1                       NaN           0
# 2                       NaN           0
# 3                       NaN           0
# 4                       NaN           0
# ...                     ...         ...
# 537668                  NaN           7
# 537669    ['grant.2684227']           8
# 537670                  NaN          12
# 537671                  NaN           1
# 537672                  NaN           0
#
#                                                     title     type volume  \
# 0       Spatial representation: How fish know their place  article     34
# 1       411.4: International graft preservation practi...  article    108
# 2       Abstract 1050: Discrete Population Of Rare Smc...  article     44
# 3       A Neural Network Model for Efficient Musculosk...  article     43
# 4       Reply to De Freitas: Social media language exp...  article    121
# ...                                                   ...      ...    ...
# 537668  Voices of the "99 Percent": The Role of Online...  article     20
# 537669  Second‐Trimester Ductus Venosus Measurement an...  article     25
# 537670  Predictors of Lung Cancer: Noteworthy Cell Typ...  article     17
# 537671  Candida albicans structural and secreted prote...  article      7
# 537672  T Cell Tolerance Following Bacterial Glutamic ...  article      3
#
#           year
# 0       2024.0
# 1       2024.0
# 2       2024.0
# 3       2024.0
# 4       2024.0
# ...        ...
# 537668  2016.0
# 537669  2006.0
# 537670  2013.0
# 537671  2010.0
# 537672  2006.0
#
# [537673 rows x 74 columns]

# %% [markdown]
# Only include publications that have funding infrormation.

# %%
df = df[df.funders.notna()]
df
# Out:
#                                                  abstract  \
# 0       Mammalian place cells are active at one or a f...
# 5       Background: Cardiac systolic dysfunction is a ...
# 7       BACKGROUND: Lung transplant recipients are tra...
# 11      Uncoupling protein 3 (UCP3) belongs to the mit...
# 15      BACKGROUND/OBJECTIVES: Trait mindfulness (TM) ...
# ...                                                   ...
# 537646  OBJECTIVES: The purpose of this study was to a...
# 537647  Atypical chronic myeloid leukemia (aCML) and c...
# 537658  The problem addressed here was to obtain optim...
# 537667  OBJECTIVES: We have developed the Early Screen...
# 537669  OBJECTIVE: The purpose of this study was to de...
#
#                                          acknowledgements  altmetric  \
# 0                                                     NaN        4.0
# 5       We are extremely grateful to each of the study...        1.0
# 7       Acknowledgments We thank the clinical coordina...        2.0
# 11      We thank Sarah Bardakji for her excellent tech...        NaN
# 15      The authors wish to thank Wendy Mansfield and ...        1.0
# ...                                                   ...        ...
# 537646  This work was presented in part at the America...        NaN
# 537647  VK is supported by a Howard Hughes Medical Ins...        NaN
# 537658  The authors acknowledge the support of US NIH/...        6.0
# 537667  We thank Aaron Baggish, MD, from Massachusetts...       55.0
# 537669  Dr Bianco is supported by National Institute o...        NaN
#
#         altmetric_id arxiv_id  \
# 0        170059067.0      NaN
# 5        165269385.0      NaN
# 7        166935404.0      NaN
# 11               0.0      NaN
# 15       159116686.0      NaN
# ...              ...      ...
# 537646           0.0      NaN
# 537647           0.0      NaN
# 537658     6070639.0      NaN
# 537667     2065344.0      NaN
# 537669           0.0      NaN
#
#                                                   authors  authors_count  \
# 0       [{'affiliations': [{'city': 'Stanford', 'city_...              2
# 5       [{'affiliations': [{'city': 'New York', 'city_...             16
# 7       [{'affiliations': [{'city': 'Bethesda', 'city_...             17
# 11      [{'affiliations': [{'city': 'Vienna', 'city_id...              3
# 15      [{'affiliations': [{'city': 'Irvine', 'city_id...              3
# ...                                                   ...            ...
# 537646  [{'affiliations': [{'city': 'New Brunswick', '...              3
# 537647  [{'affiliations': [{'city': None, 'city_id': N...              8
# 537658  [{'affiliations': [{'city': 'Houston', 'city_i...              3
# 537667  [{'affiliations': [{'city': 'Stanford', 'city_...              3
# 537669  [{'affiliations': [{'city': 'San Francisco', '...              6
#
#        book_doi book_series_title book_title  ... resulting_publication_doi  \
# 0           NaN               NaN        NaN  ...                       NaN
# 5           NaN               NaN        NaN  ...                       NaN
# 7           NaN               NaN        NaN  ...                       NaN
# 11          NaN               NaN        NaN  ...                       NaN
# 15          NaN               NaN        NaN  ...                       NaN
# ...         ...               ...        ...  ...                       ...
# 537646      NaN               NaN        NaN  ...                       NaN
# 537647      NaN               NaN        NaN  ...                       NaN
# 537658      NaN               NaN        NaN  ...                       NaN
# 537667      NaN               NaN        NaN  ...                       NaN
# 537669      NaN               NaN        NaN  ...                       NaN
#
#        score                                       source_title  \
# 0        1.0  {'id': 'jour.1101321', 'title': 'Current Biolo...
# 5        1.0  {'id': 'jour.1051506', 'title': 'Frontiers in ...
# 7        1.0  {'id': 'jour.1093601', 'title': 'The Journal o...
# 11       1.0    {'id': 'jour.1047694', 'title': 'Biomolecules'}
# 15       1.0  {'id': 'jour.1099236', 'title': 'Anxiety Stres...
# ...      ...                                                ...
# 537646   1.0  {'id': 'jour.1093318', 'title': 'Journal of Ul...
# 537647   1.0          {'id': 'jour.1047717', 'title': 'Cureus'}
# 537658   1.0  {'id': 'jour.1030663', 'title': 'Technology in...
# 537667   1.0  {'id': 'jour.1093318', 'title': 'Journal of Ul...
# 537669   1.0  {'id': 'jour.1093318', 'title': 'Journal of Ul...
#
#                                                 subtitles  \
# 0                                                     NaN
# 5                                                     NaN
# 7                                                     NaN
# 11                                                    NaN
# 15                                                    NaN
# ...                                                   ...
# 537646                           ['Room for Improvement']
# 537647                                                NaN
# 537658                                                NaN
# 537667  ['Utility of Focused Physician‐Operated Echoca...
# 537669                                                NaN
#
#                                      supporting_grant_ids times_cited  \
# 0                                                     NaN           0
# 5       ['grant.9655182', 'grant.2438793', 'grant.2542...           0
# 7                                       ['grant.2669581']           1
# 11                     ['grant.8587225', 'grant.7580350']           3
# 15      ['grant.7817921', 'grant.7070529', 'grant.9214...           4
# ...                                                   ...         ...
# 537646                                                NaN           3
# 537647  ['grant.2414443', 'grant.3860235', 'grant.3535...          44
# 537658                                  ['grant.2475796']           7
# 537667                                                NaN          34
# 537669                                  ['grant.2684227']           8
#
#                                                     title     type volume  \
# 0       Spatial representation: How fish know their place  article     34
# 5       Mechanisms of left ventricular systolic dysfun...  article     11
# 7       Extreme elevations of donor-derived cell-free ...  article     43
# 11      Uncoupling Protein 3 Catalyzes the Exchange of...  article     14
# 15      Associations between mindfulness and mental he...  article     37
# ...                                                   ...      ...    ...
# 537646  Maternal‐Fetal Medicine Fellowship 3‐ and 4‐Di...  article     32
# 537647  Durable Disease Control with MEK Inhibition in...  article      7
# 537658  IMRT Treatment Planning on 4D Geometries for t...  article     13
# 537667  Early Screening for Cardiovascular Abnormaliti...  article     33
# 537669  Second‐Trimester Ductus Venosus Measurement an...  article     25
#
#           year
# 0       2024.0
# 5       2024.0
# 7       2024.0
# 11      2023.0
# 15      2023.0
# ...        ...
# 537646  2013.0
# 537647  2015.0
# 537658  2014.0
# 537667  2014.0
# 537669  2006.0
#
# [266787 rows x 74 columns]

# %%
266787 / 537673
# Out:
# 0.49618820361074484

# %% [markdown]
# Only half of our Dimensions publications have funding information.
#
# Parse the funders information, so we can get the DoE ones. There can be more than one funder per publication.

# %%
eval(df['funders'][0])
# Out:
# [{'acronym': 'HHMI',
#   'city_name': 'Chevy Chase',
#   'country_code': 'US',
#   'country_name': 'United States',
#   'id': 'grid.413575.1',
#   'latitude': 39.021835,
#   'linkout': ['http://www.hhmi.org/'],
#   'longitude': -77.1563,
#   'name': 'Howard Hughes Medical Institute',
#   'state_name': 'Maryland',
#   'types': ['Nonprofit']}]

# %% [markdown]
# Lets get the acronyms.

# %%
df['funder_acronyms'] = df.funders.apply(lambda funders: [f.get('acronym') for f in eval(funders)])
df
# Out:
#                                                  abstract  \
# 0       Mammalian place cells are active at one or a f...
# 5       Background: Cardiac systolic dysfunction is a ...
# 7       BACKGROUND: Lung transplant recipients are tra...
# 11      Uncoupling protein 3 (UCP3) belongs to the mit...
# 15      BACKGROUND/OBJECTIVES: Trait mindfulness (TM) ...
# ...                                                   ...
# 537646  OBJECTIVES: The purpose of this study was to a...
# 537647  Atypical chronic myeloid leukemia (aCML) and c...
# 537658  The problem addressed here was to obtain optim...
# 537667  OBJECTIVES: We have developed the Early Screen...
# 537669  OBJECTIVE: The purpose of this study was to de...
#
#                                          acknowledgements  altmetric  \
# 0                                                     NaN        4.0
# 5       We are extremely grateful to each of the study...        1.0
# 7       Acknowledgments We thank the clinical coordina...        2.0
# 11      We thank Sarah Bardakji for her excellent tech...        NaN
# 15      The authors wish to thank Wendy Mansfield and ...        1.0
# ...                                                   ...        ...
# 537646  This work was presented in part at the America...        NaN
# 537647  VK is supported by a Howard Hughes Medical Ins...        NaN
# 537658  The authors acknowledge the support of US NIH/...        6.0
# 537667  We thank Aaron Baggish, MD, from Massachusetts...       55.0
# 537669  Dr Bianco is supported by National Institute o...        NaN
#
#         altmetric_id arxiv_id  \
# 0        170059067.0      NaN
# 5        165269385.0      NaN
# 7        166935404.0      NaN
# 11               0.0      NaN
# 15       159116686.0      NaN
# ...              ...      ...
# 537646           0.0      NaN
# 537647           0.0      NaN
# 537658     6070639.0      NaN
# 537667     2065344.0      NaN
# 537669           0.0      NaN
#
#                                                   authors  authors_count  \
# 0       [{'affiliations': [{'city': 'Stanford', 'city_...              2
# 5       [{'affiliations': [{'city': 'New York', 'city_...             16
# 7       [{'affiliations': [{'city': 'Bethesda', 'city_...             17
# 11      [{'affiliations': [{'city': 'Vienna', 'city_id...              3
# 15      [{'affiliations': [{'city': 'Irvine', 'city_id...              3
# ...                                                   ...            ...
# 537646  [{'affiliations': [{'city': 'New Brunswick', '...              3
# 537647  [{'affiliations': [{'city': None, 'city_id': N...              8
# 537658  [{'affiliations': [{'city': 'Houston', 'city_i...              3
# 537667  [{'affiliations': [{'city': 'Stanford', 'city_...              3
# 537669  [{'affiliations': [{'city': 'San Francisco', '...              6
#
#        book_doi book_series_title book_title  ... score  \
# 0           NaN               NaN        NaN  ...   1.0
# 5           NaN               NaN        NaN  ...   1.0
# 7           NaN               NaN        NaN  ...   1.0
# 11          NaN               NaN        NaN  ...   1.0
# 15          NaN               NaN        NaN  ...   1.0
# ...         ...               ...        ...  ...   ...
# 537646      NaN               NaN        NaN  ...   1.0
# 537647      NaN               NaN        NaN  ...   1.0
# 537658      NaN               NaN        NaN  ...   1.0
# 537667      NaN               NaN        NaN  ...   1.0
# 537669      NaN               NaN        NaN  ...   1.0
#
#                                              source_title  \
# 0       {'id': 'jour.1101321', 'title': 'Current Biolo...
# 5       {'id': 'jour.1051506', 'title': 'Frontiers in ...
# 7       {'id': 'jour.1093601', 'title': 'The Journal o...
# 11        {'id': 'jour.1047694', 'title': 'Biomolecules'}
# 15      {'id': 'jour.1099236', 'title': 'Anxiety Stres...
# ...                                                   ...
# 537646  {'id': 'jour.1093318', 'title': 'Journal of Ul...
# 537647          {'id': 'jour.1047717', 'title': 'Cureus'}
# 537658  {'id': 'jour.1030663', 'title': 'Technology in...
# 537667  {'id': 'jour.1093318', 'title': 'Journal of Ul...
# 537669  {'id': 'jour.1093318', 'title': 'Journal of Ul...
#
#                                                 subtitles  \
# 0                                                     NaN
# 5                                                     NaN
# 7                                                     NaN
# 11                                                    NaN
# 15                                                    NaN
# ...                                                   ...
# 537646                           ['Room for Improvement']
# 537647                                                NaN
# 537658                                                NaN
# 537667  ['Utility of Focused Physician‐Operated Echoca...
# 537669                                                NaN
#
#                                      supporting_grant_ids times_cited  \
# 0                                                     NaN           0
# 5       ['grant.9655182', 'grant.2438793', 'grant.2542...           0
# 7                                       ['grant.2669581']           1
# 11                     ['grant.8587225', 'grant.7580350']           3
# 15      ['grant.7817921', 'grant.7070529', 'grant.9214...           4
# ...                                                   ...         ...
# 537646                                                NaN           3
# 537647  ['grant.2414443', 'grant.3860235', 'grant.3535...          44
# 537658                                  ['grant.2475796']           7
# 537667                                                NaN          34
# 537669                                  ['grant.2684227']           8
#
#                                                     title     type volume  \
# 0       Spatial representation: How fish know their place  article     34
# 5       Mechanisms of left ventricular systolic dysfun...  article     11
# 7       Extreme elevations of donor-derived cell-free ...  article     43
# 11      Uncoupling Protein 3 Catalyzes the Exchange of...  article     14
# 15      Associations between mindfulness and mental he...  article     37
# ...                                                   ...      ...    ...
# 537646  Maternal‐Fetal Medicine Fellowship 3‐ and 4‐Di...  article     32
# 537647  Durable Disease Control with MEK Inhibition in...  article      7
# 537658  IMRT Treatment Planning on 4D Geometries for t...  article     13
# 537667  Early Screening for Cardiovascular Abnormaliti...  article     33
# 537669  Second‐Trimester Ductus Venosus Measurement an...  article     25
#
#           year                funder_acronyms
# 0       2024.0                         [HHMI]
# 5       2024.0              [NIH, NHLBI, NCI]
# 7       2024.0  [NHLBI, NCI, NIH, CFF, NIAID]
# 11      2023.0                 [FWF, EC, DFG]
# 15      2023.0  [NSF GEO, NSF SBE, NCAR, NSF]
# ...        ...                            ...
# 537646  2013.0                         [AIUM]
# 537647  2015.0      [NCI, NHGRI, HHMI, NHLBI]
# 537658  2014.0             [NHMRC, NCI, None]
# 537667  2014.0                          [MGH]
# 537669  2006.0                        [NICHD]
#
# [266787 rows x 75 columns]

# %%
doe = df[df.funder_acronyms.apply(lambda f: 'DOE' in f)]
doe
# Out:
#                                                  abstract  \
# 25                                                    NaN
# 97      The successful design of high power windows pl...
# 121     Soluble karyopherins of the importin-β (impβ) ...
# 141     The rates of methane utilization and trichloro...
# 357     Conjugated polymers are widely used materials ...
# ...                                                   ...
# 537250  Hearing and balance rely on small sensory hair...
# 537271  The linguistic foundations of science and tech...
# 537274  Identifying low-dimensional features that desc...
# 537359  Stochastic cell-surface expression of α-, β-, ...
# 537367  Activation triggers the exchange of subunits i...
#
#                                          acknowledgements  altmetric  \
# 25                                                    NaN        1.0
# 97                                                    NaN        NaN
# 121     The funders had no role in study design, data ...        2.0
# 141                                                   NaN        NaN
# 357     We thank the Bent group at Stanford University...        NaN
# ...                                                   ...        ...
# 537250  The funders had no role in study design, data ...       21.0
# 537271  We thank Ben Blencowe (University of Toronto),...       18.0
# 537274  The funders had no role in study design, data ...       16.0
# 537359  The funders had no role in study design, data ...        1.0
# 537367  The funders had no role in study design, data ...        3.0
#
#         altmetric_id arxiv_id  \
# 25       143381535.0      NaN
# 97               0.0      NaN
# 121        3772191.0      NaN
# 141              0.0      NaN
# 357              0.0      NaN
# ...              ...      ...
# 537250    69758444.0      NaN
# 537271    55793640.0      NaN
# 537274    54999439.0      NaN
# 537359   111199905.0      NaN
# 537367     6133937.0      NaN
#
#                                                   authors  authors_count  \
# 25      [{'affiliations': [{'city': 'Stanford', 'city_...              9
# 97      [{'affiliations': [{'city': 'Menlo Park', 'cit...             12
# 121     [{'affiliations': [{'city': 'London', 'city_id...              8
# 141     [{'affiliations': [{'city': 'Palmerston North'...              3
# 357     [{'affiliations': [{'city': 'Stanford', 'city_...              9
# ...                                                   ...            ...
# 537250  [{'affiliations': [{'city': 'Richland', 'city_...              8
# 537271  [{'affiliations': [{'city': 'Rethymno', 'city_...              7
# 537274  [{'affiliations': [{'city': 'Cambridge', 'city...              7
# 537359  [{'affiliations': [{'city': 'New York', 'city_...             10
# 537367  [{'affiliations': [{'city': 'Berkeley', 'city_...             15
#
#        book_doi book_series_title book_title  ... score  \
# 25          NaN               NaN        NaN  ...   1.0
# 97          NaN               NaN        NaN  ...   1.0
# 121         NaN               NaN        NaN  ...   1.0
# 141         NaN               NaN        NaN  ...   1.0
# 357         NaN               NaN        NaN  ...   1.0
# ...         ...               ...        ...  ...   ...
# 537250      NaN               NaN        NaN  ...   1.0
# 537271      NaN               NaN        NaN  ...   1.0
# 537274      NaN               NaN        NaN  ...   1.0
# 537359      NaN               NaN        NaN  ...   1.0
# 537367      NaN               NaN        NaN  ...   1.0
#
#                                              source_title subtitles  \
# 25       {'id': 'jour.1136447', 'title': 'Nature Energy'}       NaN
# 97                                                    NaN       NaN
# 121              {'id': 'jour.1046517', 'title': 'eLife'}       NaN
# 141     {'id': 'jour.1081617', 'title': 'Biotechnology...       NaN
# 357     {'id': 'jour.1041450', 'title': 'ACS Applied M...       NaN
# ...                                                   ...       ...
# 537250           {'id': 'jour.1046517', 'title': 'eLife'}       NaN
# 537271           {'id': 'jour.1046517', 'title': 'eLife'}       NaN
# 537274           {'id': 'jour.1046517', 'title': 'eLife'}       NaN
# 537359           {'id': 'jour.1046517', 'title': 'eLife'}       NaN
# 537367           {'id': 'jour.1046517', 'title': 'eLife'}       NaN
#
#                                      supporting_grant_ids times_cited  \
# 25                     ['grant.5542465', 'grant.9398648']          45
# 97                                                    NaN           0
# 121     ['grant.2699072', 'grant.2435219', 'grant.2515...         117
# 141                                                   NaN          49
# 357                                     ['grant.8691864']          21
# ...                                                   ...         ...
# 537250  ['grant.2439487', 'grant.7072077', 'grant.2489...          97
# 537271                                                NaN           5
# 537274  ['grant.7072664', 'grant.2623701', 'grant.3933...         103
# 537359  ['grant.2439737', 'grant.2516823', 'grant.2671...          61
# 537367  ['grant.2521670', 'grant.2684074', 'grant.2521...         101
#
#                                                     title        type volume  \
# 25      Author Correction: Mechanical regulation of li...     article      8
# 97      High Power Window Tests at SLAC* *Work support...  proceeding      2
# 121     Importin-β modulates the permeability of the n...     article      4
# 141     Numerical modeling and uncertainties in rate c...     article     53
# 357     Impact of the Crystallite Orientation Distribu...     article      7
# ...                                                   ...         ...    ...
# 537250  Single-cell proteomics reveals changes in expr...     article      8
# 537271  Hypothesis, analysis and synthesis, it's all G...     article      8
# 537274  Unsupervised discovery of temporal sequences i...     article      8
# 537359  γ-Protocadherin structural diversity and funct...     article      5
# 537367  Molecular mechanism of activation-triggered su...     article      5
#
#           year                                    funder_acronyms
# 25      2023.0                                [DOE, EDU, NSF ENG]
# 97      2001.0                                              [DOE]
# 121     2015.0                           [NIAID, NCI, DOE, NIGMS]
# 141     1997.0                                         [EPA, DOE]
# 357     2015.0                                         [DOE, BES]
# ...        ...                                                ...
# 537250  2019.0           [NIDCD, None, BER, NCI, HHF, NINDS, DOE]
# 537271  2019.0                                          [EC, DOE]
# 537274  2019.0  [NIBIB, Simons, OD, DOE, NIDCD, NIMH, NINDS, N...
# 537359  2016.0                    [HHMI, DOE, NSF BIO, NIGMS, OD]
# 537367  2016.0                      [HHMI, JCC, HFSP, NIGMS, DOE]
#
# [8814 rows x 75 columns]

# %%
8814 / 266787
# Out:
# 0.03303759178670625

# %% [markdown]
# Only 3.3% of funders includes the Department of Energy -- assuming that DOE is consistently used.

# %%
doe_counts = doe.value_counts('year').reset_index().sort_values('year', ascending=False)
doe_counts
# Out:
#       year  count
# 16  2024.0    279
# 14  2023.0    319
# 10  2022.0    376
# 12  2021.0    366
# 9   2020.0    397
# ..     ...    ...
# 57  1961.0      4
# 64  1960.0      1
# 58  1959.0      3
# 63  1957.0      1
# 65  1956.0      1
#
# [66 rows x 2 columns]

# %%
doe_counts['year'] = doe_counts['year'].astype('int')
doe_counts
# Out:
#     year  count
# 16  2024    279
# 14  2023    319
# 10  2022    376
# 12  2021    366
# 9   2020    397
# ..   ...    ...
# 57  1961      4
# 64  1960      1
# 58  1959      3
# 63  1957      1
# 65  1956      1
#
# [66 rows x 2 columns]

# %%
from plotly import express as xp

fig = xp.line(
    doe_counts,
    x='year',
    y='count',
    line_shape='spline',
    title='Department of Energy Funded Publications at Stanford',
    labels={'count': 'Publications', 'year': 'Year'},
    width=1000
)
fig.show('png')

# %% [markdown]
# ## RoR IDs
#
# Maybe it's a small number of DoE publications because some funders within the DoE are listed as the funder, rather than the DoE itself?
#
# For example [The Office of Environmental Management](https://ror.org/00km40770) is within the DoE.
#
# Is it possible to get a list of all the funders withink the DoE and add them? ALso perhaps we should be using the ID to match?

# %%
df['funder_ids'] = df.funders.apply(lambda funders: [f.get('id') for f in eval(funders)])
df[['doi', 'funder_ids']]
# Out:
#                                     doi  \
# 0             10.1016/j.cub.2024.09.038
# 5             10.3389/fcvm.2024.1371810
# 7          10.1016/j.healun.2024.04.064
# 11                 10.3390/biom14010021
# 15        10.1080/10615806.2023.2267454
# ...                                 ...
# 537646           10.7863/ultra.32.6.949
# 537647               10.7759/cureus.414
# 537658  10.7785/tcrtexpress.2013.600276
# 537667           10.7863/ultra.33.2.307
# 537669        10.7863/jum.2006.25.8.979
#
#                                                funder_ids
# 0                                         [grid.413575.1]
# 5           [grid.94365.3d, grid.279885.9, grid.48336.3a]
# 7       [grid.279885.9, grid.48336.3a, grid.94365.3d, ...
# 11          [grid.25111.36, grid.270680.b, grid.424150.6]
# 15      [grid.457836.b, grid.457916.8, grid.57828.30, ...
# ...                                                   ...
# 537646                                    [grid.468268.6]
# 537647  [grid.48336.3a, grid.280128.1, grid.413575.1, ...
# 537658      [grid.431143.0, grid.48336.3a, grid.417285.d]
# 537667                                    [grid.32224.35]
# 537669                                    [grid.420089.7]
#
# [266787 rows x 2 columns]

# %% [markdown]
# Now we need a list of funder IDs that are part of the DoE. Dimensions uses GRID identifiers so lets create a function that uses the ROR API and returns the GRID IDs for a given ROR ID and all its children that have GRID IDs.

# %%
import requests
import time

def grid_ids(ror_id):
    time.sleep(.25)    
    ror_id = ror_id.split('/')[-1] # remove URL portion if present
    
    org = requests.get(f'https://api.ror.org/v2/organizations/{ror_id}').json()

    # if the org has a gridid return it
    grid_id = get_grid_id(org)
    if grid_id:
        yield grid_id

    # look for gridids in child organizations
    for child_org in filter(lambda o: o['type'] == 'child', org['relationships']):
        yield from grid_ids(child_org['id'])

def get_grid_id(org):
    for id in org['external_ids']:
        if id['type'] == 'grid':
            return id['preferred']

doe_grid_ids = list(grid_ids('https://ror.org/01bj3aw27'))
doe_grid_ids
# Out:
# ['grid.85084.31',
#  'grid.452934.d',
#  'grid.484068.6',
#  'grid.454753.4',
#  'grid.453047.1',
#  'grid.451372.6',
#  'grid.453023.3',
#  'grid.250008.f',
#  'grid.474523.3',
#  'grid.148313.c',
#  'grid.509508.1',
#  'grid.481548.4',
#  'grid.474520.0',
#  'grid.474523.3',
#  'grid.509508.1',
#  'grid.510548.d',
#  'grid.467665.0',
#  'grid.453003.1',
#  'grid.419357.d',
#  'grid.453915.f',
#  'grid.483884.b',
#  'grid.453351.5',
#  'grid.453027.7',
#  'grid.481010.c',
#  'grid.457407.5',
#  'grid.451247.1',
#  'grid.480981.c',
#  'grid.453259.c',
#  'grid.451363.6',
#  'grid.483304.8',
#  'grid.480998.4',
#  'grid.453917.d',
#  'grid.481004.9',
#  'grid.467650.6',
#  'grid.453031.0',
#  'grid.417824.c',
#  'grid.453216.7',
#  'grid.453070.5',
#  'grid.452988.a',
#  'grid.452963.f',
#  'grid.453030.1',
#  'grid.507522.7',
#  'grid.453025.5',
#  'grid.483387.3',
#  'grid.507523.6',
#  'grid.184769.5',
#  'grid.509514.c',
#  'grid.451309.a',
#  'grid.484489.d',
#  'grid.499982.7',
#  'grid.451319.b',
#  'grid.187073.a',
#  'grid.509510.8',
#  'grid.202665.5',
#  'grid.511351.2',
#  'grid.417851.e',
#  'grid.135519.a',
#  'grid.503033.6',
#  'grid.451303.0',
#  'grid.511098.4',
#  'grid.436923.9',
#  'grid.451320.1',
#  'grid.445003.6',
#  'grid.509852.3',
#  'grid.512023.7',
#  'grid.511397.8',
#  'grid.450315.6',
#  'grid.481025.a',
#  'grid.453875.8',
#  'grid.453363.4',
#  'grid.467664.1',
#  'grid.431453.4',
#  'grid.510752.4',
#  'grid.480986.b']

# %% [markdown]
# Now we can look for publications with a funder that includes one of these.

# %%
doe = df[df.funder_ids.apply(lambda ids: len(set(ids) & set(doe_grid_ids)) > 0)]
doe
# Out:
#                                                  abstract  \
# 25                                                    NaN
# 97      The successful design of high power windows pl...
# 117     A multilayer stacked X-ray camera concept is d...
# 121     Soluble karyopherins of the importin-β (impβ) ...
# 141     The rates of methane utilization and trichloro...
# ...                                                   ...
# 537359  Stochastic cell-surface expression of α-, β-, ...
# 537363  Cytosolic hormone levels must be tightly contr...
# 537367  Activation triggers the exchange of subunits i...
# 537457  Identifying what broken symmetries are present...
# 537476  Metagenome assembly from short next-generation...
#
#                                          acknowledgements  altmetric  \
# 25                                                    NaN        1.0
# 97                                                    NaN        NaN
# 117                                                   NaN        NaN
# 121     The funders had no role in study design, data ...        2.0
# 141                                                   NaN        NaN
# ...                                                   ...        ...
# 537359  The funders had no role in study design, data ...        1.0
# 537363  The funders had no role in study design, data ...       25.0
# 537367  The funders had no role in study design, data ...        3.0
# 537457  We thank C. M. Varma for inspiring us to under...        2.0
# 537476  The work was supported by the National Natural...        1.0
#
#         altmetric_id arxiv_id  \
# 25       143381535.0      NaN
# 97               0.0      NaN
# 117              0.0      NaN
# 121        3772191.0      NaN
# 141              0.0      NaN
# ...              ...      ...
# 537359   111199905.0      NaN
# 537363     2282114.0      NaN
# 537367     6133937.0      NaN
# 537457   104686590.0      NaN
# 537476    79321458.0      NaN
#
#                                                   authors  authors_count  \
# 25      [{'affiliations': [{'city': 'Stanford', 'city_...              9
# 97      [{'affiliations': [{'city': 'Menlo Park', 'cit...             12
# 117     [{'affiliations': [{'city': 'Menlo Park', 'cit...              7
# 121     [{'affiliations': [{'city': 'London', 'city_id...              8
# 141     [{'affiliations': [{'city': 'Palmerston North'...              3
# ...                                                   ...            ...
# 537359  [{'affiliations': [{'city': 'New York', 'city_...             10
# 537363  [{'affiliations': [{'city': 'Stanford', 'city_...              6
# 537367  [{'affiliations': [{'city': 'Berkeley', 'city_...             15
# 537457  [{'affiliations': [{'city': 'Urbana', 'city_id...             16
# 537476  [{'affiliations': [{'city': 'Shanghai', 'city_...              6
#
#        book_doi book_series_title book_title  ...  \
# 25          NaN               NaN        NaN  ...
# 97          NaN               NaN        NaN  ...
# 117         NaN               NaN        NaN  ...
# 121         NaN               NaN        NaN  ...
# 141         NaN               NaN        NaN  ...
# ...         ...               ...        ...  ...
# 537359      NaN               NaN        NaN  ...
# 537363      NaN               NaN        NaN  ...
# 537367      NaN               NaN        NaN  ...
# 537457      NaN               NaN        NaN  ...
# 537476      NaN               NaN        NaN  ...
#
#                                              source_title subtitles  \
# 25       {'id': 'jour.1136447', 'title': 'Nature Energy'}       NaN
# 97                                                    NaN       NaN
# 117     {'id': 'jour.1046258', 'title': 'Journal of In...       NaN
# 121              {'id': 'jour.1046517', 'title': 'eLife'}       NaN
# 141     {'id': 'jour.1081617', 'title': 'Biotechnology...       NaN
# ...                                                   ...       ...
# 537359           {'id': 'jour.1046517', 'title': 'eLife'}       NaN
# 537363           {'id': 'jour.1046517', 'title': 'eLife'}       NaN
# 537367           {'id': 'jour.1046517', 'title': 'eLife'}       NaN
# 537457  {'id': 'jour.1121514', 'title': 'Journal of th...       NaN
# 537476           {'id': 'jour.1136887', 'title': 'PeerJ'}       NaN
#
#                                      supporting_grant_ids times_cited  \
# 25                     ['grant.5542465', 'grant.9398648']          45
# 97                                                    NaN           0
# 117                                                   NaN           9
# 121     ['grant.2699072', 'grant.2435219', 'grant.2515...         117
# 141                                                   NaN          49
# ...                                                   ...         ...
# 537359  ['grant.2439737', 'grant.2516823', 'grant.2671...          61
# 537363                                  ['grant.3120038']         214
# 537367  ['grant.2521670', 'grant.2684074', 'grant.2521...         101
# 537457                 ['grant.9456095', 'grant.4322193']           0
# 537476                                  ['grant.8941553']           6
#
#                                                     title        type volume  \
# 25      Author Correction: Mechanical regulation of li...     article      8
# 97      High Power Window Tests at SLAC* *Work support...  proceeding      2
# 117     Feasibility study of a ``4H'' X-ray camera bas...     article     11
# 121     Importin-β modulates the permeability of the n...     article      4
# 141     Numerical modeling and uncertainties in rate c...     article     53
# ...                                                   ...         ...    ...
# 537359  γ-Protocadherin structural diversity and funct...     article      5
# 537363  Abscisic acid dynamics in roots detected with ...     article      3
# 537367  Molecular mechanism of activation-triggered su...     article      5
# 537457  Search for Q ∼ 0 Order near a Forbidden Bragg ...     article     90
# 537476  Deconvolute individual genomes from metagenome...     article      8
#
#           year                  funder_acronyms  \
# 25      2023.0              [DOE, EDU, NSF ENG]
# 97      2001.0                            [DOE]
# 117     2016.0                           [NNSA]
# 121     2015.0         [NIAID, NCI, DOE, NIGMS]
# 141     1997.0                       [EPA, DOE]
# ...        ...                              ...
# 537359  2016.0  [HHMI, DOE, NSF BIO, NIGMS, OD]
# 537363  2014.0              [LBL, NSF BIO, SRC]
# 537367  2016.0    [HHMI, JCC, HFSP, NIGMS, DOE]
# 537457  2021.0            [ANL, LBL, BES, None]
# 537476  2020.0                      [BER, NSFC]
#
#                                                funder_ids
# 25          [grid.85084.31, grid.457799.1, grid.457810.f]
# 97                                        [grid.85084.31]
# 117                                       [grid.453023.3]
# 121     [grid.419681.3, grid.48336.3a, grid.85084.31, ...
# 141                        [grid.418698.a, grid.85084.31]
# ...                                                   ...
# 537359  [grid.413575.1, grid.85084.31, grid.457768.f, ...
# 537363      [grid.184769.5, grid.457768.f, grid.208387.6]
# 537367  [grid.413575.1, grid.430738.b, grid.488590.8, ...
# 537457  [grid.187073.a, grid.184769.5, grid.452988.a, ...
# 537476                     [grid.452963.f, grid.419696.5]
#
# [27162 rows x 76 columns]

# %%
doe_counts = doe.value_counts('year').reset_index().sort_values('year', ascending=False)
doe_counts['year'] = doe_counts['year'].astype('int')
doe_counts = doe_counts[doe_counts.year != 2025]

fig = xp.line(
    doe_counts,
    x='year',
    y='count',
    line_shape='spline',
    title='Department of Energy Funded Publications at Stanford',
    labels={'count': 'Publications', 'year': 'Year'},
    width=1000,
    height=600
)
fig.show('png')

# %%
len(doe_grid_ids)
# Out:
# 74
