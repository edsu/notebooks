# %% [markdown]
# # Ferguson Activists
#
# This notebook contains some work I've been doing with Bergis Jules and Mosi Secret
# to investigate tweets from Ferguson activists who have died. These activists
# include:
#
# * Darren Seals
# * Edward Crawford
# * Bassem Masri
# * Deandre Joshua
# * Danye Jones
#
# The analysis depends on several tweet datasets that were collected as part of
# the Documenting the Now projects. So in order to work with the original data you will need access.

# %% [markdown]
# ## Fetch the data

# %% [markdown]
# ```
# aws s3 sync s3://mith-bags/4D41FEA7-9E85-45B8-9499-362212278CAB data/4D41FEA7-9E85-45B8
# -9499-362212278CAB
# aws s3 sync s3://mith-bags/AE0A86DE-E17D-438E-BCDF-AA1F04851CAF data/AE0A86DE-E17D-438E
# -BCDF-AA1F04851CAF
# aws s3 sync s3://mith-bags/D651C3F6-5619-4A42-A8BC-7C22B7A9A44A data/D651C3F6-5619-4A42
# -A8BC-7C22B7A9A44A
# aws s3 sync s3://mith-bags/fe28a093-d3f4-42d7-83ba-f5ba1b1cc765 data/fe28a093-d3f4-42d7
# -83ba-f5ba1b1cc765
# ```

# %% [markdown]
# ## Filter the Data
#
# Rather than working on the full dataset of many millions of tweets we will take a pass through all the tweets and look for ones that are relevant for the users we are interested in. Note, this will run for a day or so:

# %%
#!/usr/bin/env python3

import csv
import sys
import glob
import gzip
import json

from twarc.json2csv import get_row, get_headings

queries = [
    {
        "name": "Darren Seals",
        "screen_name": "KingDSeals",
        "user_id": "2747681903"
    },
    {
        "name": "Edward Crawford",
        "screen_name": "eyeFLOODpanties",
        "user_id": "84946406"
    },
    {
        "name": "Bassem Masri",
        "screen_name": "bassem_masri",
        "user_id": "2734647354"
    },
    {
        "name": "Deandre Joshua",
        "screen_name": None,
        "user_id": None
    },
    {
        "name": "Danye Jones",
        "screen_name": None,
        "user_id": None
    }
]

data_dirs = [
    {
        "name": "Beyond the Hashtags",
        "glob": "data/AE0A86DE-E17D-438E-BCDF-AA1F04851CAF/data/tweets/*.txt.gz"
    },
    {
        "name": "BlackLivesMatter",
        "glob": "data/4D41FEA7-9E85-45B8-9499-362212278CAB/data/*.json.gz",
    },
    {
        "name": "Ferguson Scrape",
        "glob": "data/D651C3F6-5619-4A42-A8BC-7C22B7A9A44A/data/*.json.gz",
    },
    {
        "name": "Ferguson",
        "glob": "data/fe28a093-d3f4-42d7-83ba-f5ba1b1cc765/data/*.json.gz"
    }
]

def filter_tweets():
    out = csv.writer(open("data/ferguson-activists.csv", "w"))
    out.writerow(get_headings() + ['dataset', 'file', 'user_match', 'match_type'])
    for d in data_dirs:
        for f in glob.glob(d['glob']):
            sys.stdout.write('\n{}:'.format(f))
            sys.stdout.flush()
            process_file(d['name'], f, out)

def process_file(source, json_path, out):
    for line in gzip.open(json_path):
        try:
            tweet = json.loads(line)
        except:
            continue
        match = tweet_match(tweet)
        if match:
            sys.stdout.write('.')
            sys.stdout.flush()
            out.writerow(get_row(tweet) + [source, json_path] + match)

def tweet_match(t):
    for q in queries:

        # tweet by the user?
        if q['user_id'] == t['user']['id_str']:
            if t['in_reply_to_user_id_str']:
                return [q['name'], 'replied']
            elif t.get('retweeted_status') is not None:
                return [q['name'], 'retweeted']
            else:
                return [q['name'], 'posted']

        # someone replied to a tweet by the user?
        if q['user_id'] and q['user_id'] == t['in_reply_to_user_id_str']:
            return [q['name'], 'replied to']

        # user reweeted by someone else?
        rt = t.get('retweeted_status')
        if rt and q['user_id'] == rt['user']['id_str']:
            return [q['name'], 'user retweeted']

        # user mentioned by someone else?
        for u in t['entities'].get('user_mentions', []):
            if q['user_id'] == u['id_str']:
                return [q['name'], 'user mentioned']

        # someone mentioned them by name?
        text = t.get('text') or t.get('full_text')
        text = text.lower()
        if q['name'].lower() in text:
            return [q['name'], 'name mention']

    return None

# %% [markdown]
# ## Query the data
#
# We created a CSV of the tweet data in the previous step, but now lets convert it to a sqlite database so we can query it.

# %%
import sqlite3

db = sqlite3.connect('data/ferguson-activists.db')

# %% [markdown]
# See what users the activists replied to the most:

# %%
q = """
    SELECT 
      user_screen_name,
      in_reply_to_screen_name,
      COUNT(*) AS total
    FROM results
    WHERE
      match_type = "replied"
    GROUP BY
      user_screen_name,
      in_reply_to_screen_name
    HAVING
      total > 1
    ORDER BY
      user_screen_name,
      total DESC
    """
    
for result in db.execute(q):
    print(result)
# Out:
# ('KingDSeals', 'KingDSeals', 12)
# ('KingDSeals', 'DefJamRecords', 6)
# ('KingDSeals', 'MrChuckD', 6)
# ('KingDSeals', 'deray', 6)
# ('KingDSeals', 'kendricklamar', 5)
# ('KingDSeals', 'AZEALIABANKS', 4)
# ('KingDSeals', 'TefPoe', 4)
# ('KingDSeals', 'myfabolouslife', 4)
# ('KingDSeals', 'youngbuck', 4)
# ('KingDSeals', 'BarackObama', 3)
# ('KingDSeals', 'MasterPMiller', 3)
# ('KingDSeals', 'ShetheStreet', 3)
# ('KingDSeals', 'TalibKweli', 3)
# ('KingDSeals', 'TheRevAl', 3)
# ('KingDSeals', 'lostvoices14', 3)
# ('KingDSeals', 'AntonioFrench', 2)
# ('KingDSeals', 'Complex', 2)
# ('KingDSeals', 'DeplorableSunny', 2)
# ('KingDSeals', 'FTP_2015', 2)
# ('KingDSeals', 'FortuneMagazine', 2)
# ('KingDSeals', 'FunnyMaine', 2)
# ('KingDSeals', 'JColeNC', 2)
# ('KingDSeals', 'JuanMThompson', 2)
# ('KingDSeals', 'KingJames', 2)
# ('KingDSeals', 'Nettaaaaaaaa', 2)
# ('KingDSeals', 'SybrinaFulton', 2)
# ('KingDSeals', 'TheDreadPoet', 2)
# ('KingDSeals', 'TupacShakurST', 2)
# ('KingDSeals', 'allhiphopcom', 2)
# ('KingDSeals', 'bassem_masri', 2)
# ('KingDSeals', 'common', 2)
# ('KingDSeals', 'davidbanner', 2)
# ('KingDSeals', 'es_snipes', 2)
# ('KingDSeals', 'icecube', 2)
# ('KingDSeals', 'lattegriot', 2)
# ('KingDSeals', 'mtvhiphop', 2)
# ('KingDSeals', 'omyword', 2)
# ('KingDSeals', 'standingup2', 2)
# ('bassem_masri', 'bassem_masri', 241)
# ('bassem_masri', 'TefPoe', 17)
# ('bassem_masri', 'OpFerguson', 12)
# ('bassem_masri', 'GovJayNixon', 10)
# ('bassem_masri', 'stlcountypd', 9)
# ('bassem_masri', 'T_DUBB_O', 7)
# ('bassem_masri', 'Hauckers', 6)
# ('bassem_masri', 'mirahwood', 6)
# ('bassem_masri', 'RaniaKhalek', 5)
# ('bassem_masri', 'ajamazing', 5)
# ('bassem_masri', 'anthonyshahid1', 5)
# ('bassem_masri', '3ofhartsGarden', 4)
# ('bassem_masri', 'CNN', 4)
# ('bassem_masri', 'CassandraRules', 4)
# ('bassem_masri', 'ChrisHayesTV', 4)
# ('bassem_masri', 'Delo_Taylor', 4)
# ('bassem_masri', 'ImRikaJai', 4)
# ('bassem_masri', 'JadoreKENNEDY', 4)
# ('bassem_masri', 'Jeannie_Parr', 4)
# ('bassem_masri', 'Lnonblonde', 4)
# ('bassem_masri', 'NorthSTLCounty', 4)
# ('bassem_masri', 'Nothiefsallowed', 4)
# ('bassem_masri', 'Rebelutionary_Z', 4)
# ('bassem_masri', 'glirette', 4)
# ('bassem_masri', 'rextrabextra', 4)
# ('bassem_masri', 'skankbones', 4)
# ('bassem_masri', 'ucfulidiot', 4)
# ('bassem_masri', 'wshemp', 4)
# ('bassem_masri', 'AltRightInfo', 3)
# ('bassem_masri', 'AnonCopWatch', 3)
# ('bassem_masri', 'AnonIntelGroup', 3)
# ('bassem_masri', 'AnonLove253FTP', 3)
# ('bassem_masri', 'AnonyMobLive', 3)
# ('bassem_masri', 'ChristinaKSDK', 3)
# ('bassem_masri', 'CommanderXanon', 3)
# ('bassem_masri', 'CruzIncRadio', 3)
# ('bassem_masri', 'FRANI20', 3)
# ('bassem_masri', 'Ferguson__Guy', 3)
# ('bassem_masri', 'FundFerguson', 3)
# ('bassem_masri', 'Jeffmw', 3)
# ('bassem_masri', 'ReadCONTRA', 3)
# ('bassem_masri', 'RetiredHandle', 3)
# ('bassem_masri', 'Shaggy_TheAngel', 3)
# ('bassem_masri', 'SophiaLamar1', 3)
# ('bassem_masri', 'TheSailor2014', 3)
# ('bassem_masri', 'VanguardTNT', 3)
# ('bassem_masri', 'dreamhampton', 3)
# ('bassem_masri', 'handsupunited_', 3)
# ('bassem_masri', 'mariclaire81', 3)
# ('bassem_masri', 'moonbeam0811', 3)
# ('bassem_masri', 'sarasidnerCNN', 3)
# ('bassem_masri', 'scottishtoodler', 3)
# ('bassem_masri', 'sdwilkins3019', 3)
# ('bassem_masri', 'typicalcircle', 3)
# ('bassem_masri', 'withoutwingz', 3)
# ('bassem_masri', 'AntonioFrench', 2)
# ('bassem_masri', 'BlackGClouds', 2)
# ('bassem_masri', 'Cheese_Gravy', 2)
# ('bassem_masri', 'ChingonaRasta', 2)
# ('bassem_masri', 'ChristineDByers', 2)
# ('bassem_masri', 'Colorado2108', 2)
# ('bassem_masri', 'DLoesch', 2)
# ('bassem_masri', 'DamnationNow', 2)
# ('bassem_masri', 'DarrisTestimony', 2)
# ('bassem_masri', 'DefConAlert', 2)
# ('bassem_masri', 'DiaaMahmoud', 2)
# ('bassem_masri', 'Downinthe210', 2)
# ('bassem_masri', 'FoxNews', 2)
# ('bassem_masri', 'HowNowBrownDowd', 2)
# ('bassem_masri', 'JohnnyMack_', 2)
# ('bassem_masri', 'KKKOfficial311', 2)
# ('bassem_masri', 'Kermit_Progress', 2)
# ('bassem_masri', 'LadyJudahJr', 2)
# ('bassem_masri', 'Lambityann', 2)
# ('bassem_masri', 'LetsLow', 2)
# ('bassem_masri', 'Mogaza', 2)
# ('bassem_masri', 'Ms_Workes', 2)
# ('bassem_masri', 'MustafaASN', 2)
# ('bassem_masri', 'NikoWavy', 2)
# ('bassem_masri', 'NubianQueenIAm', 2)
# ('bassem_masri', 'PDPJ', 2)
# ('bassem_masri', 'PIX2CLICK', 2)
# ('bassem_masri', 'PamSchep', 2)
# ('bassem_masri', 'PolitiBunny', 2)
# ('bassem_masri', 'RebelDiaz', 2)
# ('bassem_masri', 'ShaunKing', 2)
# ('bassem_masri', 'SteveStenger', 2)
# ('bassem_masri', 'TalibKweli', 2)
# ('bassem_masri', 'That_Guy_19033', 2)
# ('bassem_masri', 'ThisBIGSHAQ', 2)
# ('bassem_masri', 'TonyTheHIITMan', 2)
# ('bassem_masri', 'WhyJustBeth', 2)
# ('bassem_masri', 'YankeeSkum', 2)
# ('bassem_masri', 'clantro', 2)
# ('bassem_masri', 'classysportsfan', 2)
# ('bassem_masri', 'colleenkelly', 2)
# ('bassem_masri', 'dafnegs', 2)
# ('bassem_masri', 'deray', 2)
# ('bassem_masri', 'dingalingy55', 2)
# ('bassem_masri', 'divineem', 2)
# ('bassem_masri', 'jasonredonnelly', 2)
# ('bassem_masri', 'justagirlatl', 2)
# ('bassem_masri', 'kbpellett314', 2)
# ('bassem_masri', 'megameg96', 2)
# ('bassem_masri', 'mtaylor1211', 2)
# ('bassem_masri', 'my2cnz', 2)
# ('bassem_masri', 'nativekittens', 2)
# ('bassem_masri', 'rochellek14', 2)
# ('bassem_masri', 'search4swag', 2)
# ('bassem_masri', 'shariline', 2)
# ('bassem_masri', 'stabier', 2)
# ('bassem_masri', 'starletwilliams', 2)
# ('bassem_masri', 'tribex_stl', 2)
# ('bassem_masri', 'user95815', 2)
# ('eyeFLOODpanties', 'Tip', 2)
# ('eyeFLOODpanties', 'darth__mouth', 2)
# ('eyeFLOODpanties', 'joshuamahony', 2)

# %% [markdown]
# What does this look like as a nework? First create the graph.

# %%
import networkx

replies_g = networkx.DiGraph()
for from_user, to_user, count in db.execute(q):
    if from_user == to_user:
        continue
    replies_g.add_node(from_user)
    replies_g.add_node(to_user)
    replies_g.add_edge(from_user, to_user, weight=count)

# %% [markdown]
# Now create a function to visualize the graph with pyvis. I'm copying this little handy function from another project:

# %%
import pyvis

def label(s):
    if len(s) > 40:
        return s[0:10]
    return s

def vis(g, html_path, width="100%", height=600):
    degree = g.degree(g)
        
    v = pyvis.network.Network(notebook=True, height=height, width=width, directed=True)
    for src, dst, data in g.edges(data=True):
        v.add_node(src, label(src), title=src, value=degree[src], color='#ccc')
        v.add_node(dst, label(dst), title=dst, value=degree[dst], color='lightgreen')
        v.add_edge(src, dst, value=data['weight'])
        
    
    v.set_options('{"edges":{"color":{"inherit":true},"smooth":false},"physics":{"forceAtlas2Based":{"springLength":50},"minVelocity":0.75,"solver":"forceAtlas2Based"}}')
    return v.show(html_path)

vis(replies_g, 'data/replies.html')
# Out:
#         <iframe
#             width="100%"
#             height="600"
#             src="data/replies.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# We can do a similar query to see who the users are retweeting:

# %%
q = """
    SELECT 
      user_screen_name,
      retweet_or_quote_screen_name,
      COUNT(*) AS total
    FROM results
    WHERE
      match_type = "retweeted"
    GROUP BY
      user_screen_name,
      retweet_or_quote_screen_name
    HAVING
      total > 1
    ORDER BY
      user_screen_name,
      total DESC
    """
    
for result in db.execute(q):
    print(result)
# Out:
# ('KingDSeals', 'bassem_masri', 30)
# ('KingDSeals', 'VanguardTNT', 10)
# ('KingDSeals', 'davidbanner', 7)
# ('KingDSeals', 'RE_invent_ED', 5)
# ('KingDSeals', 'TheOutlawz', 5)
# ('KingDSeals', 'ImRikaJai', 4)
# ('KingDSeals', 'T_DUBB_O', 4)
# ('KingDSeals', 'YOUNG_NOBLE1', 4)
# ('KingDSeals', 'brothercartan', 4)
# ('KingDSeals', 'handsupunited_', 4)
# ('KingDSeals', 'tariqnasheed', 4)
# ('KingDSeals', 'Gimme_A_Break1', 3)
# ('KingDSeals', 'TefPoe', 3)
# ('KingDSeals', 'jjmcphatter', 3)
# ('KingDSeals', 'lostvoices14', 3)
# ('KingDSeals', 'mikebrowncover', 3)
# ('KingDSeals', 'neweryork', 3)
# ('KingDSeals', 'Cherrell_Brown', 2)
# ('KingDSeals', 'ChuckModi1', 2)
# ('KingDSeals', 'Khan_SHEGOG', 2)
# ('KingDSeals', 'Nettaaaaaaaa', 2)
# ('KingDSeals', 'OwlsAsylum', 2)
# ('KingDSeals', 'dlatchison011', 2)
# ('KingDSeals', 'guygruber', 2)
# ('KingDSeals', 'peaceful_birdie', 2)
# ('KingDSeals', 'youthradio', 2)
# ('King_D_Seals', 'THEREALBANNER', 7)
# ('bassem_masri', 'Delo_Taylor', 203)
# ('bassem_masri', 'sarahkendzior', 45)
# ('bassem_masri', 'deray', 41)
# ('bassem_masri', 'handsupunited_', 40)
# ('bassem_masri', 'CruzIncRadio', 36)
# ('bassem_masri', 'TefPoe', 26)
# ('bassem_masri', 'Cygnussid42', 24)
# ('bassem_masri', 'Lnonblonde', 24)
# ('bassem_masri', 'dejahsmommy', 24)
# ('bassem_masri', 'AntonioFrench', 22)
# ('bassem_masri', 'Hauckers', 22)
# ('bassem_masri', 'RE_invent_ED', 22)
# ('bassem_masri', 'CassandraRules', 21)
# ('bassem_masri', 'Jeannie_Hartley', 21)
# ('bassem_masri', 'CruzInc4u', 20)
# ('bassem_masri', 'NYC2Palestine', 18)
# ('bassem_masri', 'SeanSharesStuff', 18)
# ('bassem_masri', 'typicalcircle', 18)
# ('bassem_masri', 'AnonCopWatch', 17)
# ('bassem_masri', 'norarahimian', 17)
# ('bassem_masri', 'ImRikaJai', 16)
# ('bassem_masri', 'Just4Emanuel9', 15)
# ('bassem_masri', 'PenofUmar', 15)
# ('bassem_masri', 'ChristinaKSDK', 14)
# ('bassem_masri', 'AnonyMobLive', 13)
# ('bassem_masri', 'HatchHarkness', 13)
# ('bassem_masri', 'MungenCakes', 13)
# ('bassem_masri', 'my2cnz', 13)
# ('bassem_masri', 'KWRose', 12)
# ('bassem_masri', 'ReadCONTRA', 12)
# ('bassem_masri', 'i_AM_theChange', 12)
# ('bassem_masri', 'mikebrowncover', 12)
# ('bassem_masri', 'Hotflashes10', 11)
# ('bassem_masri', 'RaniaKhalek', 11)
# ('bassem_masri', 'TheVikChick', 11)
# ('bassem_masri', 'YourAnonNews', 11)
# ('bassem_masri', 'AnonFerg', 10)
# ('bassem_masri', 'AnonLove253FTP', 10)
# ('bassem_masri', 'Nettaaaaaaaa', 10)
# ('bassem_masri', 'Rebelutionary_Z', 10)
# ('bassem_masri', 'ChingonaRasta', 9)
# ('bassem_masri', 'VanguardTNT', 9)
# ('bassem_masri', 'CinnaAyn', 8)
# ('bassem_masri', 'CruzIncGlobal', 8)
# ('bassem_masri', 'IsakandRbka', 8)
# ('bassem_masri', 'KatCapps', 8)
# ('bassem_masri', 'justinstoned', 8)
# ('bassem_masri', 'stop1033', 8)
# ('bassem_masri', 'ChuckModi1', 7)
# ('bassem_masri', 'Cleosbaby64', 7)
# ('bassem_masri', 'MissJupiter1957', 7)
# ('bassem_masri', 'Ms_Workes', 7)
# ('bassem_masri', 'OwlsAsylum', 7)
# ('bassem_masri', 'StlGal_36', 7)
# ('bassem_masri', 'WyzeChef', 7)
# ('bassem_masri', 'kash04316_d', 7)
# ('bassem_masri', 'mollyrosestl', 7)
# ('bassem_masri', 'pbj_stl13', 7)
# ('bassem_masri', 'BlackGClouds', 6)
# ('bassem_masri', 'IdalinBobe', 6)
# ('bassem_masri', 'SMoKeeGyRL', 6)
# ('bassem_masri', 'nubian_1', 6)
# ('bassem_masri', 'sdkstl', 6)
# ('bassem_masri', 'wshemp', 6)
# ('bassem_masri', 'ILoveMyWife0007', 5)
# ('bassem_masri', 'LeslieMac', 5)
# ('bassem_masri', 'Mayberry200', 5)
# ('bassem_masri', 'MintPressNews', 5)
# ('bassem_masri', 'OpFerguson', 5)
# ('bassem_masri', 'bdoulaoblongata', 5)
# ('bassem_masri', 'dolphin_LS', 5)
# ('bassem_masri', 'drumbeats4peace', 5)
# ('bassem_masri', 'jrosenbaum', 5)
# ('bassem_masri', 'lsarsour', 5)
# ('bassem_masri', 'mirahwood', 5)
# ('bassem_masri', 'raydowns', 5)
# ('bassem_masri', 'tchopstl_', 5)
# ('bassem_masri', 'thewanji', 5)
# ('bassem_masri', 'Anna_Baltzer', 4)
# ('bassem_masri', 'AnonymousPress', 4)
# ('bassem_masri', 'CNN', 4)
# ('bassem_masri', 'Ellevation_', 4)
# ('bassem_masri', 'Kelemchrist', 4)
# ('bassem_masri', 'LAPeoplesMedia', 4)
# ('bassem_masri', 'LaminSwann', 4)
# ('bassem_masri', 'Nechanna', 4)
# ('bassem_masri', 'Shanna_Parker', 4)
# ('bassem_masri', 'T_DUBB_O', 4)
# ('bassem_masri', 'TalibKweli', 4)
# ('bassem_masri', 'angeldevil1111', 4)
# ('bassem_masri', 'bexology_', 4)
# ('bassem_masri', 'deathrep', 4)
# ('bassem_masri', 'maryteatowel', 4)
# ('bassem_masri', 'mel_takes_pics', 4)
# ('bassem_masri', 'rousseau_ist', 4)
# ('bassem_masri', 'search4swag', 4)
# ('bassem_masri', 't0p_100', 4)
# ('bassem_masri', 'verbal_riot', 4)
# ('bassem_masri', 'AB_Syed', 3)
# ('bassem_masri', 'AVASradiance', 3)
# ('bassem_masri', 'AnitaStewart', 3)
# ('bassem_masri', 'BellaEiko', 3)
# ('bassem_masri', 'Bohemianmoon', 3)
# ('bassem_masri', 'Copwatch', 3)
# ('bassem_masri', 'CourtneyPFB', 3)
# ('bassem_masri', 'DConford', 3)
# ('bassem_masri', 'FaithInFerguson', 3)
# ('bassem_masri', 'GeekNStereo', 3)
# ('bassem_masri', 'GlobalRevLive', 3)
# ('bassem_masri', 'JCoopPhoto', 3)
# ('bassem_masri', 'JohnnyMack_', 3)
# ('bassem_masri', 'JoyAnnReid', 3)
# ('bassem_masri', 'MelodyTheMellow', 3)
# ('bassem_masri', 'NewsRevo', 3)
# ('bassem_masri', 'NubianQueenIAm', 3)
# ('bassem_masri', 'PMbeers', 3)
# ('bassem_masri', 'Pie324', 3)
# ('bassem_masri', 'PresidentFraud', 3)
# ('bassem_masri', 'SherriQueenMoma', 3)
# ('bassem_masri', 'TheDreadPoet', 3)
# ('bassem_masri', 'TheNYCBMX', 3)
# ('bassem_masri', 'TheZOMB', 3)
# ('bassem_masri', 'anthonyshahid1', 3)
# ('bassem_masri', 'argusnewsnow', 3)
# ('bassem_masri', 'brandonlongo', 3)
# ('bassem_masri', 'cgrapski', 3)
# ('bassem_masri', 'devotedones', 3)
# ('bassem_masri', 'iJesseWilliams', 3)
# ('bassem_masri', 'j7vii', 3)
# ('bassem_masri', 'kavn', 3)
# ('bassem_masri', 'kaybunce', 3)
# ('bassem_masri', 'longgoneblond', 3)
# ('bassem_masri', 'moonbeam0811', 3)
# ('bassem_masri', 'mterr337', 3)
# ('bassem_masri', 'overtherye', 3)
# ('bassem_masri', 'phampel', 3)
# ('bassem_masri', 'prussogirl', 3)
# ('bassem_masri', 'queenlintlicker', 3)
# ('bassem_masri', 'sarasidnerCNN', 3)
# ('bassem_masri', 'stacielovestea', 3)
# ('bassem_masri', 'stlpsc', 3)
# ('bassem_masri', '12160mhz', 2)
# ('bassem_masri', '88blackhatss', 2)
# ('bassem_masri', 'ABernM', 2)
# ('bassem_masri', 'Amazing32582', 2)
# ('bassem_masri', 'Anon_OpSK', 2)
# ('bassem_masri', 'Anondad', 2)
# ('bassem_masri', 'ArrestWilson', 2)
# ('bassem_masri', 'Auntie_Allison', 2)
# ('bassem_masri', 'BigBull45', 2)
# ('bassem_masri', 'Blackstarjus', 2)
# ('bassem_masri', 'Chaosforthefly', 2)
# ('bassem_masri', 'ChristNme', 2)
# ('bassem_masri', 'CigarDaisy311', 2)
# ('bassem_masri', 'CommanderXanon', 2)
# ('bassem_masri', 'CynnyB', 2)
# ('bassem_masri', 'De400blues', 2)
# ('bassem_masri', 'DeadPrecariat', 2)
# ('bassem_masri', 'DemondFernandez', 2)
# ('bassem_masri', 'DesignsInCode', 2)
# ('bassem_masri', 'Erberhawk', 2)
# ('bassem_masri', 'FergusonMafia', 2)
# ('bassem_masri', 'Fiveonadub', 2)
# ('bassem_masri', 'GC4Hillary', 2)
# ('bassem_masri', 'GrlMeechie', 2)
# ('bassem_masri', 'HowNowBrownDowd', 2)
# ('bassem_masri', 'IAM_aVOICE', 2)
# ('bassem_masri', 'JASVPUMP', 2)
# ('bassem_masri', 'JessLivMo', 2)
# ('bassem_masri', 'JesseBenn', 2)
# ('bassem_masri', 'Jmoon901', 2)
# ('bassem_masri', 'KINGofMONSTARS', 2)
# ('bassem_masri', 'KickGamePropers', 2)
# ('bassem_masri', 'LiberalHDWoman', 2)
# ('bassem_masri', 'MercutioXanon', 2)
# ('bassem_masri', 'MidWestMisfit13', 2)
# ('bassem_masri', 'NAGOUL1', 2)
# ('bassem_masri', 'OBS_STL', 2)
# ('bassem_masri', 'OLAASM', 2)
# ('bassem_masri', 'OccHiloMedia', 2)
# ('bassem_masri', 'OccuWorld', 2)
# ('bassem_masri', 'OchiProp', 2)
# ('bassem_masri', 'POTUSIsLOVED44', 2)
# ('bassem_masri', 'PaulKWeinhold', 2)
# ('bassem_masri', 'Penny_G', 2)
# ('bassem_masri', 'Platypus64', 2)
# ('bassem_masri', 'PolicePoliceACP', 2)
# ('bassem_masri', 'RationalBassist', 2)
# ('bassem_masri', 'RisePDX', 2)
# ('bassem_masri', 'SeattleKennetha', 2)
# ('bassem_masri', 'SophiaLamar1', 2)
# ('bassem_masri', 'T_H_E_F_A_C_E', 2)
# ('bassem_masri', 'Thisl', 2)
# ('bassem_masri', 'TinaGaston87', 2)
# ('bassem_masri', 'Truth573', 2)
# ('bassem_masri', 'US_Campaign', 2)
# ('bassem_masri', 'WesleyLowery', 2)
# ('bassem_masri', 'Yamiche', 2)
# ('bassem_masri', '_Elle_Spencer_', 2)
# ('bassem_masri', 'aaronRmcmullin', 2)
# ('bassem_masri', 'adbridgeforth', 2)
# ('bassem_masri', 'ageless_vintage', 2)
# ('bassem_masri', 'amnestyusa', 2)
# ('bassem_masri', 'backonmylizzie', 2)
# ('bassem_masri', 'bleedingheartmx', 2)
# ('bassem_masri', 'brownblaze', 2)
# ('bassem_masri', 'ccchicky', 2)
# ('bassem_masri', 'chriskingstl', 2)
# ('bassem_masri', 'common', 2)
# ('bassem_masri', 'damkina', 2)
# ('bassem_masri', 'doccivilwarsr', 2)
# ('bassem_masri', 'dreamhampton', 2)
# ('bassem_masri', 'evenbev', 2)
# ('bassem_masri', 'eyeseeslive', 2)
# ('bassem_masri', 'fergusonRus', 2)
# ('bassem_masri', 'jaa4th', 2)
# ('bassem_masri', 'jimprincems', 2)
# ('bassem_masri', 'jonswaine', 2)
# ('bassem_masri', 'justinbaragona', 2)
# ('bassem_masri', 'kgosztola', 2)
# ('bassem_masri', 'kittygal5399', 2)
# ('bassem_masri', 'lamproce', 2)
# ('bassem_masri', 'limeonaire', 2)
# ('bassem_masri', 'maccalled', 2)
# ('bassem_masri', 'minefield101', 2)
# ('bassem_masri', 'msugrl33', 2)
# ('bassem_masri', 'myownspin', 2)
# ('bassem_masri', 'occupytheory', 2)
# ('bassem_masri', 'pastormykmac', 2)
# ('bassem_masri', 'realmelodic', 2)
# ('bassem_masri', 'ronfullwood', 2)
# ('bassem_masri', 'sacourtreporter', 2)
# ('bassem_masri', 'sarsoora834', 2)
# ('bassem_masri', 'sepulvev', 2)
# ('bassem_masri', 'shazza_razza', 2)
# ('bassem_masri', 'sophiaponders', 2)
# ('bassem_masri', 'soylentgs', 2)
# ('bassem_masri', 'stephencdeere', 2)
# ('bassem_masri', 'stevenjhsieh', 2)
# ('bassem_masri', 'stlouisx50', 2)
# ('bassem_masri', 'stubbscrew', 2)
# ('eyeFLOODpanties', 'kodacohen', 12)
# ('eyeFLOODpanties', 'PDPJ', 4)
# ('eyeFLOODpanties', 'Tedderman1', 4)
# ('eyeFLOODpanties', 'DylanPlayfair', 3)
# ('eyeFLOODpanties', '_LadyT23', 3)
# ('eyeFLOODpanties', 'AntonioFrench', 2)
# ('eyeFLOODpanties', 'Bigcee56', 2)
# ('eyeFLOODpanties', 'Bipartisanism', 2)
# ('eyeFLOODpanties', 'Breaking911', 2)
# ('eyeFLOODpanties', 'CocoDivinexxx', 2)
# ('eyeFLOODpanties', 'ElanMartinDCLaw', 2)
# ('eyeFLOODpanties', 'FierceBeautyCo', 2)
# ('eyeFLOODpanties', 'HazeyKilla', 2)
# ('eyeFLOODpanties', 'KadieUSA', 2)
# ('eyeFLOODpanties', 'MrsTKidd', 2)
# ('eyeFLOODpanties', 'MzJonesEsq', 2)
# ('eyeFLOODpanties', 'Nettaaaaaaaa', 2)
# ('eyeFLOODpanties', 'Rebelutionary_Z', 2)
# ('eyeFLOODpanties', 'ReignOfApril', 2)
# ('eyeFLOODpanties', 'SavingEJ', 2)
# ('eyeFLOODpanties', 'StrangePintura', 2)
# ('eyeFLOODpanties', 'TheCubicleChick', 2)
# ('eyeFLOODpanties', 'TheObamaDiary', 2)
# ('eyeFLOODpanties', 'WallyBeamin', 2)
# ('eyeFLOODpanties', 'brianstelter', 2)
# ('eyeFLOODpanties', 'coolmamamia', 2)
# ('eyeFLOODpanties', 'deray', 2)
# ('eyeFLOODpanties', 'drewXdeficit', 2)
# ('eyeFLOODpanties', 'drgoddess', 2)
# ('eyeFLOODpanties', 'jadewalkerr21', 2)
# ('eyeFLOODpanties', 'jaywise3', 2)
# ('eyeFLOODpanties', 'kentuckyviews', 2)
# ('eyeFLOODpanties', 'kreactivity', 2)
# ('eyeFLOODpanties', 'lana_heart300', 2)
# ('eyeFLOODpanties', 'lataysimp', 2)
# ('eyeFLOODpanties', 'newsjunke', 2)
# ('eyeFLOODpanties', 'reneefranks', 2)
# ('eyeFLOODpanties', 'sauvignonelle', 2)

# %% [markdown]
# The retweet network looks interesting because bassem_masri and KingDSeals are retweeting each other. Let's create a network visualization of the retweets.

# %%
retweets_g = networkx.DiGraph()
for from_user, to_user, count in db.execute(q):
    if from_user == to_user:
        continue
    retweets_g.add_node(from_user)
    retweets_g.add_node(to_user)
    retweets_g.add_edge(from_user, to_user, weight=count)

vis(retweets_g, 'data/retweets.html')
# Out:
#         <iframe
#             width="100%"
#             height="600"
#             src="data/retweets.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# This one has a bit more structure. Of the three activists we have retweet data for, the only Twitter user that all three have retweeted was Nettaaaaaaaa (Johnetta Elzie).
